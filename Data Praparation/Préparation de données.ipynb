# %% [markdown]
# # <h1><center>data analysis with python</center></h1>

# %% [markdown]
# <h2>Table of Contents</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ol>
#     <li><a href="#data_acquisition">Data Acquisition</a>
#     <li><a href="#basic_insight">Basic Insight of Dataset</a></li>
# </ol>
#
# </div>
# <hr>

# %% [markdown]
# Importing libraries

# %%
#on import pandas et numpy 
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#On import notre dataset
pathfile = "C:/Users/Avicii/Desktop/Samad/GI2/Projet de fin d'etude/PredictiveModel/data/data.xlsx"
df = pd.read_excel(pathfile)
df.head()
# Out:
#                Horodateur   sexe  age logement filiere  endroit_travail  \
# 0 2020-02-24 22:22:24.019  Homme   21  Interne      GI             Cafè
# 1 2020-03-05 20:20:16.644  Homme   18  Interne     CP1  La Bibliothèque
# 2 2020-03-05 21:08:41.865  Homme   21  Interne      GI             Cafè
# 3 2020-03-05 21:38:14.244  Homme   18  Externe     CP2             Cafè
# 4 2020-03-05 22:39:30.718  Homme   21  Interne      GC         Chez moi
#
#   travail_equipe  heure_dormir  sport_par_sem activites_para  ...  \
# 0             Non      00:00:00        2 fois            oui  ...
# 1             Non      02:00:00             5            Oui  ...
# 2             Oui      01:00:00        3 fois            Oui  ...
# 3             Oui      02:00:00             5            Oui  ...
# 4             Oui      01:00:00        3 fois            Non  ...
#
#   ressources_materials Mauvais_Gestion_temps qualite_logement  \
# 0                  Non                   Oui              Oui
# ...

# %%
#determiner les dimensions du dataframe
df.shape
# Out:
# (402, 31)

# %%
#show columns 
df.columns
# Out:
# Index(['Horodateur', 'sexe', 'age', 'logement', 'filiere', 'endroit_travail',
#        'travail_equipe ', 'heure_dormir ', 'sport_par_sem', 'activites_para',
#        'rythme_formation ', 'compétences_enseignants ',
#        'communication_enseignants', 'méthodes_pédagogiques',
#        'etat_psychique_preparation ', 'etat_psychique_examen',
#        'resultat_etudiant', 'nombre_rattrapage', 'services_bibliothèques',
#        'transport_scolaire', 'orientation', 'ressources_materials',
#        'Mauvais_Gestion_temps', 'qualite_logement', 'addiction_drogues',
#        'mauvais_choix_de_cours', 'réseaux_sociaux', 'Barrieres_de_langage',
#        'l'entourage', 'gaming', 'Unnamed: 30'],
#       dtype='object')

# %%
# check the data type of data frame "df" by .dtypes
print(df.dtypes)
# Out:
# Horodateur                     datetime64[ns]
# sexe                                   object
# age                                     int64
# logement                               object
# filiere                                object
# endroit_travail                        object
# travail_equipe                         object
# heure_dormir                           object
# sport_par_sem                          object
# activites_para                         object
# rythme_formation                       object
# compétences_enseignants                object
# communication_enseignants              object
# méthodes_pédagogiques                  object
# etat_psychique_preparation             object
# etat_psychique_examen                  object
# resultat_etudiant                      object
# nombre_rattrapage                       int64
# services_bibliothèques                 object
# transport_scolaire                     object
# ...

# %% [markdown]
# <h2>Describe</h2>
# If we would like to get a statistical summary of each column, such as count, column mean value, column standard deviation, etc. We use the describe method:

# %%
df.describe()
# Out:
#               age  nombre_rattrapage  Unnamed: 30
# count  402.000000         402.000000          0.0
# mean    20.101990           1.457711          NaN
# std      2.431515           1.337901          NaN
# min     17.000000           0.000000          NaN
# 25%     19.000000           0.000000          NaN
# 50%     20.000000           1.000000          NaN
# 75%     21.000000           2.000000          NaN
# max     56.000000           5.000000          NaN

# %% [markdown]
# This method will provide various summary statistics, excluding <code>NaN</code> (Not a Number) values.

# %% [markdown]
# This shows the statistical summary of all numeric-typed (int, float) columns.
# For example, the attribute "age" has 402 counts, the mean value of this column is 20.012, the standard deviation is 1.64, the minimum value is 17 th percentile is 19, 50th percentile is 20, 75th percentile is 21, and the maximum value is 25.
# However, what if we would also like to check all the columns including those that are of type object.

# %% [markdown]
# we can add an argument <code>include = "all"</code> inside the bracket. Let's try it again.

# %%
# describe all the columns in "df" 
df.describe(include = "all")
# Out:
#                         Horodateur   sexe         age logement filiere  \
# count                          402    402  402.000000      402     401
# unique                         402      2         NaN        2       8
# top     2020-03-19 22:54:18.667000  Homme         NaN  Interne     CP1
# freq                             1    232         NaN      231     128
# first   2020-02-24 22:22:24.019000    NaN         NaN      NaN     NaN
# last    2020-03-26 15:12:41.517000    NaN         NaN      NaN     NaN
# mean                           NaN    NaN   20.101990      NaN     NaN
# std                            NaN    NaN    2.431515      NaN     NaN
# min                            NaN    NaN   17.000000      NaN     NaN
# 25%                            NaN    NaN   19.000000      NaN     NaN
# 50%                            NaN    NaN   20.000000      NaN     NaN
# 75%                            NaN    NaN   21.000000      NaN     NaN
# ...

# %% [markdown]
# <p>
# Now, it provides the statistical summary of all the columns, including object-typed attributes.<br>
# We can now see how many unique values, which is the top value and the frequency of top value in the object-typed columns.<br>
# Some values in the table above show as "NaN", this is because those numbers are not available regarding a particular column type.<br>
# </p>

# %%
df.head()
# Out:
#                Horodateur   sexe  age logement filiere  endroit_travail  \
# 0 2020-02-24 22:22:24.019  Homme   21  Interne      GI             Cafè
# 1 2020-03-05 20:20:16.644  Homme   18  Interne     CP1  La Bibliothèque
# 2 2020-03-05 21:08:41.865  Homme   21  Interne      GI             Cafè
# 3 2020-03-05 21:38:14.244  Homme   18  Externe     CP2             Cafè
# 4 2020-03-05 22:39:30.718  Homme   21  Interne      GC         Chez moi
#
#   travail_equipe  heure_dormir  sport_par_sem activites_para  ...  \
# 0             Non      00:00:00        2 fois            oui  ...
# 1             Non      02:00:00             5            Oui  ...
# 2             Oui      01:00:00        3 fois            Oui  ...
# 3             Oui      02:00:00             5            Oui  ...
# 4             Oui      01:00:00        3 fois            Non  ...
#
#   ressources_materials Mauvais_Gestion_temps qualite_logement  \
# 0                  Non                   Oui              Oui
# ...

# %% [markdown]
# <h1>Data Wrangling</h1>

# %% [markdown]
# Data Wrangling is the process of converting data from the initial format to a format that may be better for analysis.

# %% [markdown]
# <h2>Table of content</h2>
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
# <ul>
#     <li><a href="#identify_handle_missing_values">Identify and handle missing values</a>
#         <ul>
#             <li><a href="#identify_missing_values">Identify missing values</a></li>
#             <li><a href="#deal_missing_values">Deal with missing values</a></li>
#             <li><a href="#correct_data_format">Correct data format</a></li>
#         </ul>
#     </li>
#     <li><a href="#data_standardization">Data standardization</a></li>
#     <li><a href="#data_normalization">Data Normalization (centering/scaling)</a></li>
#     <li><a href="#binning">Binning</a></li>
#     <li><a href="#indicator">Indicator variable</a></li>
# </ul>
#
# </div>
#
# <hr>

# %% [markdown]
# <h3 id="identify_missing_values">Identify missing values</h3>

# %% [markdown]
# dentify_missing_values
#
# <h4>Evaluating for Missing Data</h4>
#
# The missing values are converted to Python's default. We use Python's built-in functions to identify these missing values. There are two methods to detect missing data:
# <ol>
#     <li><b>.isnull()</b></li>
#     <li><b>.notnull()</b></li>
# </ol>
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data.

# %%
missing_data = df.isnull()
missing_data.head(5)
# Out:
#    Horodateur   sexe    age  logement  filiere  endroit_travail  \
# 0       False  False  False     False    False            False
# 1       False  False  False     False    False            False
# 2       False  False  False     False    False            False
# 3       False  False  False     False    False            False
# 4       False  False  False     False    False            False
#
#    travail_equipe   heure_dormir   sport_par_sem  activites_para  ...  \
# 0            False          False          False           False  ...
# 1            False          False          False           False  ...
# 2            False          False          False           False  ...
# 3            False          False          False           False  ...
# 4            False          False          False           False  ...
#
#    ressources_materials  Mauvais_Gestion_temps  qualite_logement  \
# 0                 False                  False             False
# ...

# %% [markdown]
# "True" stands for missing value, while "False" stands for not missing value.

# %% [markdown]
# <h4>Count missing values in each column</h4>
# <p>
# Using a for loop in Python, we can quickly figure out the number of missing values in each column. As mentioned above, "True" represents a missing value, "False"  means the value is present in the dataset.  In the body of the for loop the method  ".value_counts()"  counts the number of "True" values.
# </p>

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print (missing_data[column].value_counts())
    print("")
# Out:
# Horodateur
# False    402
# Name: Horodateur, dtype: int64
#
# sexe
# False    402
# Name: sexe, dtype: int64
#
# age
# False    402
# Name: age, dtype: int64
#
# logement
# False    402
# Name: logement, dtype: int64
#
# filiere
# False    401
# True       1
# Name: filiere, dtype: int64
#
# endroit_travail
# False    402
# Name: endroit_travail, dtype: int64
#
# travail_equipe
# False    402
# Name: travail_equipe , dtype: int64
#
# heure_dormir
# False    402
# Name: heure_dormir , dtype: int64
#
# sport_par_sem
# False    402
# Name: sport_par_sem, dtype: int64
#
# activites_para
# False    402
# Name: activites_para, dtype: int64
#
# rythme_formation
# False    402
# Name: rythme_formation , dtype: int64
#
# compétences_enseignants
# False    402
# Name: compétences_enseignants , dtype: int64
#
# communication_enseignants
# False    402
# Name: communication_enseignants, dtype: int64
#
# méthodes_pédagogiques
# False    402
# Name: méthodes_pédagogiques, dtype: int64
#
# ...

# %% [markdown]
# Based on the summary above, each column has 205 rows of data, seven columns containing missing data:
# <ol>
#     <li>"filiere": 1 missing data</li>
#
# </ol>

# %% [markdown]
# <h3 id="deal_missing_values">Deal with missing data</h3>
# <b>How to deal with missing data?</b>
#
# <ol>
#     <li>drop data<br>
#         a. drop the whole row<br>
#         b. drop the whole column
#     </li>
#     <li>replace data<br>
#         a. replace it by mean<br>
#         b. replace it by frequency<br>
#         c. replace it based on other functions
#     </li>
# </ol>

# %% [markdown]
# Whole columns should be dropped only if most entries in the column are empty. In our dataset, none of the columns are empty enough to drop entirely.
# We have some freedom in choosing which method to replace data; however, some methods may seem more reasonable than others. We will apply each method to many different columns:
#
# <b>Replace by mean:</b>
# <ul>
#     <li>"normalized-losses": 41 missing data, replace them with mean</li>
#     <li>"stroke": 4 missing data, replace them with mean</li>
#     <li>"bore": 4 missing data, replace them with mean</li>
#     <li>"horsepower": 2 missing data, replace them with mean</li>
#     <li>"peak-rpm": 2 missing data, replace them with mean</li>
# </ul>
#
# <b>Replace by frequency:</b>
# <ul>
#     <li>"num-of-doors": 2 missing data, replace them with "four".
#
#
# </ul>
#
# <b>Drop the whole row:</b>
# <ul>
#
# </ul>

# %%
#<h4>Calculate the mean value for '' column</h4>
#avg_bore=df['bore'].astype('float').mean(axis=0)
#print("Average of bore:", avg_bore)

# %% [markdown]
# <h4>Replace NaN by mean value</h4>

# %%
#df["bore"].replace(np.nan, avg_bore, inplace=True)

# %% [markdown]
# To see which values are present in a particular column, we can use the ".value_counts()" method:

# %%
#suprimer des headers 
del df['Unnamed: 30']
del df ['Horodateur']

# %%
df['filiere'].value_counts()
# Out:
# CP1      128
# CP2      114
# GI        66
# GC        48
# GEER      19
# GEE       18
# Autre      5
# autre      3
# Name: filiere, dtype: int64

# %% [markdown]
# We can see that four doors are the most common type. We can also use the ".idxmax()" method to calculate for us the most common type automatically:

# %%
df['filiere'].value_counts().idxmax()
# Out:
# 'CP1'

# %% [markdown]
# The replacement procedure is very similar to what we have seen previously

# %%
#replace the missing 'num-of-doors' values by the most frequent 
#df["filiere"].replace(np.nan, "CP1", inplace=True)
#on change la valeur des delemenets 'Autre' & 'autre'
df.loc[df["filiere"] == "Autre", "filiere"] = "GEER"
df.loc[df["filiere"] =="autre","filiere"] ="GEE"
df['filiere'].value_counts()
# Out:
# CP1     128
# CP2     114
# GI       66
# GC       48
# GEER     24
# GEE      21
# Name: filiere, dtype: int64

# %% [markdown]
# La meme chose pour le column "age"

# %%
df["age"].value_counts()
# Out:
# 19    98
# 18    75
# 20    72
# 21    63
# 22    53
# 23    29
# 17     7
# 25     2
# 24     2
# 56     1
# Name: age, dtype: int64

# %% [markdown]
# La Valeur 56 est illogique alors on va la remplacer par le median age

# %%
#clean the the data : exemple age =56 ???
#en remplace la valeur 56 par la moyenne age : mean 
df.loc[df["age"] ==56,"age"] = 20
df["age"].value_counts()
# Out:
# 19    98
# 18    75
# 20    73
# 21    63
# 22    53
# 23    29
# 17     7
# 25     2
# 24     2
# Name: age, dtype: int64

# %% [markdown]
# "spor_par_sem"

# %%
df["sport_par_sem"].value_counts()
# Out:
# jamais                153
# 3 fois                 84
# une fois               58
# Occasionnellment       58
# 2 fois                 32
# 5                       5
# 4                       3
# 5 fois                  2
# 7                       2
# 4 fois                  1
# Occasionnellement       1
# 3 ou plus               1
# Parfois                 1
# Occa                    1
# Name: sport_par_sem, dtype: int64

# %% [markdown]
# On change ces valeur en variables categoriques

# %%
#on change les valeures 
df.loc[df["sport_par_sem"] =="Occasionnellment","sport_par_sem"] ="rarement"
df.loc[df["sport_par_sem"] =="Occasionnellement ","sport_par_sem"] ="rarement"
df.loc[df["sport_par_sem"] =="Occa","sport_par_sem"] ="rarement"
df.loc[df["sport_par_sem"] =="2 fois","sport_par_sem"] ="parfois"
df.loc[df["sport_par_sem"] == 7,"sport_par_sem"] ="jamais"
df.loc[df["sport_par_sem"] == 5,"sport_par_sem"] ="jamais"
df.loc[df["sport_par_sem"] == 4,"sport_par_sem"] ="quelquefois"
df.loc[df["sport_par_sem"] == "3 fois","sport_par_sem"] ="quelquefois"
df.loc[df["sport_par_sem"] == "4 fois ","sport_par_sem"] ="quelquefois"
df.loc[df["sport_par_sem"] == "3 ou plus","sport_par_sem"] ="quelquefois"
df.loc[df["sport_par_sem"] == "une fois","sport_par_sem"] ="parfois"
df.loc[df["sport_par_sem"] == "Parfois ","sport_par_sem"] ="parfois"
df.loc[df["sport_par_sem"] == "5 fois ","sport_par_sem"] ="jamais"
df["sport_par_sem"].value_counts()
# Out:
# jamais         162
# parfois         91
# quelquefois     89
# rarement        60
# Name: sport_par_sem, dtype: int64

# %%
#on change l'ancienne valeur par "jamais"
df.loc[df["sport_par_sem"] == "kenna w mab9inash a khoya","sport_par_sem"] ="jamais"

# %% [markdown]
# on change les valeur pour la column :"resultat_etudiant"

# %%
df["resultat_etudiant"].value_counts()
# Out:
# Non    268
# Oui    134
# Name: resultat_etudiant, dtype: int64

# %%
df.loc[df["resultat_etudiant"] == "Non","resultat_etudiant"] ="R"
df.loc[df["resultat_etudiant"] == "Oui","resultat_etudiant"] ="V"
df["resultat_etudiant"].value_counts()
# Out:
# R    268
# V    134
# Name: resultat_etudiant, dtype: int64

# %%
df.loc[df["activites_para"] =="oui","activites_para"] ="Oui"
df.to_excel("version0.xlsx")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     310             try:
# --> 311                 self._store_workbook()
#     312             except IOError as e:
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     626         except IOError as e:
# --> 627             raise e
#     628
#
# ~\Anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     624             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 625                                 allowZip64=self.allow_zip64)
#     626         except IOError as e:
#
# ~\Anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1206                 try:
# -> 1207                     self.fp = io.open(file, filemode)
# ...

# %% [markdown]
# <h3>Dans cette etape on transforme tous les valeurs "Oui" par 1 et "Non" par 0 :</h3>

# %%
#d'abord on convert les variables qualitatives en variables quantitatifes
#on remplace  "Oui " par 1 et  les valeurs "Non" par 0
df = df.replace(to_replace="Oui", value=1)
df = df.replace(to_replace="Non", value=0)
df.head()
# Out:
#     sexe  age logement filiere  endroit_travail  travail_equipe   \
# 0  Homme   21  Interne      GI             Cafè                0
# 1  Homme   18  Interne     CP1  La Bibliothèque                0
# 2  Homme   21  Interne      GI             Cafè                1
# 3  Homme   18  Externe     CP2             Cafè                1
# 4  Homme   21  Interne      GC         Chez moi                1
#
#   heure_dormir  sport_par_sem  activites_para rythme_formation   ...  \
# 0      00:00:00       parfois               1           correct  ...
# 1      02:00:00        jamais               1         trop lent  ...
# 2      01:00:00   quelquefois               1         trop lent  ...
# 3      02:00:00        jamais               1           correct  ...
# 4      01:00:00   quelquefois               0         trop lent  ...
#
#   orientation ressources_materials Mauvais_Gestion_temps qualite_logement  \
# 0           0                    0                     1                1
# ...

# %%
#df.to_excel("version1.xlsx")

# %% [markdown]
# <h3 id="correct_data_format">Correct data format</h3>
# <b>We are almost there!</b>
# <p>The last step in data cleaning is checking and making sure that all data is in the correct format (int, float, text or other).</p>
#
# In Pandas, we use
# <p><b>.dtype()</b> to check the data type</p>
# <p><b>.astype()</b> to change the data type</p>

# %%
df.dtypes
# Out:
# sexe                           object
# age                             int64
# logement                       object
# filiere                        object
# endroit_travail                object
# travail_equipe                  int64
# heure_dormir                   object
# sport_par_sem                  object
# activites_para                  int64
# rythme_formation               object
# compétences_enseignants        object
# communication_enseignants      object
# méthodes_pédagogiques          object
# etat_psychique_preparation     object
# etat_psychique_examen          object
# resultat_etudiant              object
# nombre_rattrapage               int64
# services_bibliothèques          int64
# transport_scolaire              int64
# orientation                     int64
# ressources_materials            int64
# Mauvais_Gestion_temps           int64
# qualite_logement                int64
# addiction_drogues               int64
# mauvais_choix_de_cours          int64
# ...

# %% [markdown]
# <p>As we can see above, some columns are not of the correct data type. Numerical variables should have type 'float' or 'int', and variables with strings such as categories should have type 'object'. For example, 'bore' and 'stroke' variables are numerical values that describe the engines, so we should expect them to be of the type 'float' or 'int'; however, they are shown as type 'object'. We have to convert data types into a proper format for each column using the "astype()" method.</p>

# %% [markdown]
# <h4>Convert data types to proper format</h4>

# %% [markdown]
# <h4>Let us list the columns after the conversion</h4>

# %% [markdown]
# Now, we finally obtain the cleaned dataset with no missing values and all data in its proper format.

# %% [markdown]
# <h2 id="data_standardization">Data Standardization</h2>

# %% [markdown]
# <p>Standardization is the process of transforming data into a common format which allows the researcher to make the meaningful comparison.
# </p>

# %% [markdown]
# <h2 id="data_normalization">Data Normalization</h2>
#
# <b>Why normalization?</b>
# <p>Normalization is the process of transforming values of several variables into a similar range. Typical normalizations include scaling the variable so the variable average is 0, scaling the variable so the variance is 1, or scaling variable so the variable values range from 0 to 1
# </p>

# %%
#exemple
# replace (original value) by (original value)/(maximum value)
#df['length'] = df['length']/df['length'].max()

# %% [markdown]
# <h2 id="binning">Binning</h2>
# <b>Why binning?</b>
# <p>
#     Binning is a process of transforming continuous numerical variables into discrete categorical 'bins', for grouped analysis.
# </p>

# %% [markdown]
# <h2 id="indicator">Indicator variable (or dummy variable)</h2>
# <b>What is an indicator variable?</b>
# <p>
#     An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning.
# </p>
#
# <b>Why we use indicator variables?</b>
# <p>
#     So we can use categorical variables for regression analysis in the later modules.
# </p>
# <b>Example</b>
# <p>
#     We see the column "sexe" has two unique values, "Femme" or "Homme". Regression doesn't understand words, only numbers. To use this attribute in regression analysis, we convert "fuel-type" into indicator variables.
# </p>
#
# <p>
#     We will use the panda's method 'get_dummies' to assign numerical values to different categories of fuel type.
# </p>

# %%
df.columns
# Out:
# Index(['sexe', 'age', 'logement', 'filiere', 'endroit_travail',
#        'travail_equipe ', 'heure_dormir ', 'sport_par_sem', 'activites_para',
#        'rythme_formation ', 'compétences_enseignants ',
#        'communication_enseignants', 'méthodes_pédagogiques',
#        'etat_psychique_preparation ', 'etat_psychique_examen',
#        'resultat_etudiant', 'nombre_rattrapage', 'services_bibliothèques',
#        'transport_scolaire', 'orientation', 'ressources_materials',
#        'Mauvais_Gestion_temps', 'qualite_logement', 'addiction_drogues',
#        'mauvais_choix_de_cours', 'réseaux_sociaux', 'Barrieres_de_langage',
#        'l'entourage', 'gaming'],
#       dtype='object')

# %% [markdown]
# get indicator variables and assign it to data frame "dummy_variable_1"

# %%
dummy_variable_1 = pd.get_dummies(df["sexe"])
dummy_variable_1.head()
# Out:
#    Femme  Homme
# 0      0      1
# 1      0      1
# 2      0      1
# 3      0      1
# 4      0      1

# %% [markdown]
# change column names for clarity

# %%
dummy_variable_1.rename(columns={'sexe':'Femme', 'sexe':'Homme'}, inplace=True)
dummy_variable_1.head()
# Out:
#    Femme  Homme
# 0      0      1
# 1      0      1
# 2      0      1
# 3      0      1
# 4      0      1

# %% [markdown]
# We now have the value 0 to represent "Femme" and 1 to represent "Homme" in the column "sexe". We will now insert this column back into our original dataset.

# %%
# merge data frame "df" and "dummy_variable_1" 
df = pd.concat([df, dummy_variable_1], axis=1)

# drop original column "sexe" from "df"
df.drop("sexe", axis = 1, inplace=True)

# %%
df.head()
# Out:
#    age logement filiere  endroit_travail  travail_equipe  heure_dormir   \
# 0   21  Interne      GI             Cafè                0      00:00:00
# 1   18  Interne     CP1  La Bibliothèque                0      02:00:00
# 2   21  Interne      GI             Cafè                1      01:00:00
# 3   18  Externe     CP2             Cafè                1      02:00:00
# 4   21  Interne      GC         Chez moi                1      01:00:00
#
#   sport_par_sem  activites_para rythme_formation  compétences_enseignants   \
# 0       parfois               1           correct                  faibles
# 1        jamais               1         trop lent                  faibles
# 2   quelquefois               1         trop lent                  faibles
# 3        jamais               1           correct                  faibles
# 4   quelquefois               0         trop lent                  faibles
#
#    ... Mauvais_Gestion_temps qualite_logement addiction_drogues  \
# ...

# %% [markdown]
# The last two columns are now the indicator variable representation of the gender variable. It's all 0s and 1s now.

# %%
df.dtypes
# Out:
# age                             int64
# logement                       object
# filiere                        object
# endroit_travail                object
# travail_equipe                  int64
# heure_dormir                   object
# sport_par_sem                  object
# activites_para                  int64
# rythme_formation               object
# compétences_enseignants        object
# communication_enseignants      object
# méthodes_pédagogiques          object
# etat_psychique_preparation     object
# etat_psychique_examen          object
# resultat_etudiant              object
# nombre_rattrapage               int64
# services_bibliothèques          int64
# transport_scolaire              int64
# orientation                     int64
# ressources_materials            int64
# Mauvais_Gestion_temps           int64
# qualite_logement                int64
# addiction_drogues               int64
# mauvais_choix_de_cours          int64
# réseaux_sociaux                 int64
# ...

# %% [markdown]
# le meme chose pour la column "logement"

# %%
dummy_variable_2 = pd.get_dummies(df["logement"])
dummy_variable_2.head()
# Out:
#    Externe  Interne
# 0        0        1
# 1        0        1
# 2        0        1
# 3        1        0
# 4        0        1

# %%
# merge data frame "df" and "dummy_variable_2" 
df = pd.concat([df, dummy_variable_2], axis=1)

# drop original column "sexe" from "df"
df.drop("logement", axis = 1, inplace=True)
df.head()
# Out:
#    age filiere  endroit_travail  travail_equipe  heure_dormir  sport_par_sem  \
# 0   21      GI             Cafè                0      00:00:00       parfois
# 1   18     CP1  La Bibliothèque                0      02:00:00        jamais
# 2   21      GI             Cafè                1      01:00:00   quelquefois
# 3   18     CP2             Cafè                1      02:00:00        jamais
# 4   21      GC         Chez moi                1      01:00:00   quelquefois
#
#    activites_para rythme_formation  compétences_enseignants   \
# 0               1           correct                  faibles
# 1               1         trop lent                  faibles
# 2               1         trop lent                  faibles
# 3               1           correct                  faibles
# 4               0         trop lent                  faibles
#
#   communication_enseignants  ... addiction_drogues mauvais_choix_de_cours  \
# ...

# %%
df.corr()
# Out:
#                              age  travail_equipe   activites_para  \
# age                     1.000000         0.068856        0.016591
# travail_equipe          0.068856         1.000000        0.197740
# activites_para          0.016591         0.197740        1.000000
# nombre_rattrapage      -0.106007        -0.053337       -0.053521
# services_bibliothèques  0.006499        -0.007571       -0.084434
# transport_scolaire     -0.027209         0.064340        0.025236
# orientation            -0.055768        -0.036080       -0.002120
# ressources_materials    0.168783         0.068236        0.183598
# Mauvais_Gestion_temps   0.032204        -0.110190       -0.027231
# qualite_logement        0.010371        -0.002035       -0.005499
# addiction_drogues       0.141048         0.032914       -0.013166
# mauvais_choix_de_cours -0.002803         0.039129        0.053001
# réseaux_sociaux        -0.106438        -0.028350        0.028274
# ...

# %% [markdown]
# <h2>Continuous numerical variables:</h2>
#
# <p>Continuous numerical variables are variables that may contain any value within some range. Continuous numerical variables can have the type "int64" or "float64". A great way to visualize these variables is by using scatterplots with fitted lines.</p>
#
# <p>In order to start understanding the (linear) relationship between an individual variable and the price. We can do this by using "regplot", which plots the scatterplot plus the fitted regression line for the data.</p>

# %% [markdown]
#  Let's see several examples of different linear relationships:

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="Interne", y="qualite_logement", data=df)
plt.ylim(0,)
# Out:
# (0, 1.0508637826320935)

# %%
# Engine size as potential predictor variable of price
sns.regplot(x="Mauvais_Gestion_temps", y="nombre_rattrapage", data=df)
plt.ylim(0,)
# Out:
# (0, 5.252433541453878)

# %% [markdown]
# <h3>Categorical variables</h3>
#
# <p>These are variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. The categorical variables can have the type "object" or "int64". A good way to visualize categorical variables is by using boxplots.</p>

# %%
sns.boxplot(x="endroit_travail", y="nombre_rattrapage", data=df)

# %% [markdown]
# On voit ici qu'il ya une relation entre l'edroit du travail et le nombre du rattrapage d'etudiants

# %%
sns.boxplot(x="sport_par_sem", y="nombre_rattrapage", data=df)

# %% [markdown]
# il ya une relation entre le nombre de rattrapage et le sport

# %%
sns.boxplot(x="etat_psychique_examen", y="nombre_rattrapage", data=df)

# %%
df.describe()
# Out:
#               age  travail_equipe   activites_para  nombre_rattrapage  \
# count  402.000000       402.000000      402.000000         402.000000
# mean    20.012438         0.385572        0.507463           1.457711
# std      1.640310         0.487337        0.500567           1.337901
# min     17.000000         0.000000        0.000000           0.000000
# 25%     19.000000         0.000000        0.000000           0.000000
# 50%     20.000000         0.000000        1.000000           1.000000
# 75%     21.000000         1.000000        1.000000           2.000000
# max     25.000000         1.000000        1.000000           5.000000
#
#        services_bibliothèques  transport_scolaire  orientation  \
# count              402.000000          402.000000   402.000000
# mean                 0.236318            0.181592     0.402985
# std                  0.425349            0.385988     0.491109
# min                  0.000000            0.000000     0.000000
# ...

# %% [markdown]
#  The default setting of "describe" skips variables of type object. We can apply the method "describe" on the variables of type 'object' as follows:

# %%
df.describe(include=['object'])
# Out:
#        filiere endroit_travail heure_dormir  sport_par_sem rythme_formation   \
# count      401             402           402           402               402
# unique       6               3            40             4                 3
# top        CP1        Chez moi      01:00:00        jamais           correct
# freq       128             202            89           162               156
#
#        compétences_enseignants  communication_enseignants  \
# count                       402                       402
# unique                        5                         3
# top                     pas mal     Moyennement satisfait
# freq                        238                       224
#
#         méthodes_pédagogiques etat_psychique_preparation   \
# count                     402                         402
# unique                      3                           3
# top     Moyennement satisfait                     Stressé
# ...

# %%
from scipy import stats

# %%
pearson_coef, p_value = stats.pearsonr(df['réseaux_sociaux'], df['nombre_rattrapage'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.05255692119892459  with a P-value of P = 0.29316292029064084

# %%
df.columns
# Out:
# Index(['age', 'filiere', 'endroit_travail', 'travail_equipe ', 'heure_dormir ',
#        'sport_par_sem', 'activites_para', 'rythme_formation ',
#        'compétences_enseignants ', 'communication_enseignants',
#        'méthodes_pédagogiques', 'etat_psychique_preparation ',
#        'etat_psychique_examen', 'resultat_etudiant', 'nombre_rattrapage',
#        'services_bibliothèques', 'transport_scolaire', 'orientation',
#        'ressources_materials', 'Mauvais_Gestion_temps', 'qualite_logement',
#        'addiction_drogues', 'mauvais_choix_de_cours', 'réseaux_sociaux',
#        'Barrieres_de_langage', 'l'entourage', 'gaming', 'Femme', 'Homme',
#        'Externe', 'Interne'],
#       dtype='object')

# %%
pearson_coef, p_value = stats.pearsonr(df['Mauvais_Gestion_temps'], df['nombre_rattrapage'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.09481465521907595  with a P-value of P = 0.057513319341477374

# %% [markdown]
#  we will explore several methods to see if certain characteristics or features can be used to predict student performance.

# %% [markdown]
# <h3>What are the main characteristics which have the most impact on the student performance ?</h3>

# %%
df.head()
# Out:
#    age filiere  endroit_travail  travail_equipe  heure_dormir  sport_par_sem  \
# 0   21      GI             Cafè                0      00:00:00       parfois
# 1   18     CP1  La Bibliothèque                0      02:00:00        jamais
# 2   21      GI             Cafè                1      01:00:00   quelquefois
# 3   18     CP2             Cafè                1      02:00:00        jamais
# 4   21      GC         Chez moi                1      01:00:00   quelquefois
#
#    activites_para rythme_formation  compétences_enseignants   \
# 0               1           correct                  faibles
# 1               1         trop lent                  faibles
# 2               1         trop lent                  faibles
# 3               1           correct                  faibles
# 4               0         trop lent                  faibles
#
#   communication_enseignants  ... addiction_drogues mauvais_choix_de_cours  \
# ...

# %% [markdown]
# <h2 id="pattern_visualization">2. Analyzing Individual Feature Patterns using Visualization</h2>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

#to plote in Jupyter notebook.
# %matplotlib inline

# %% [markdown]
# <h4>How to choose the right visualization method?</h4>
# <p>When visualizing individual variables, it is important to first understand what type of variable you are dealing with. This will help us find the right visualization method for that variable.</p>

# %%
df.corr()
# Out:
#                              age  travail_equipe   activites_para  \
# age                     1.000000         0.068856        0.016591
# travail_equipe          0.068856         1.000000        0.197740
# activites_para          0.016591         0.197740        1.000000
# nombre_rattrapage      -0.106007        -0.053337       -0.053521
# services_bibliothèques  0.006499        -0.007571       -0.084434
# transport_scolaire     -0.027209         0.064340        0.025236
# orientation            -0.055768        -0.036080       -0.002120
# ressources_materials    0.168783         0.068236        0.183598
# Mauvais_Gestion_temps   0.032204        -0.110190       -0.027231
# qualite_logement        0.010371        -0.002035       -0.005499
# addiction_drogues       0.141048         0.032914       -0.013166
# mauvais_choix_de_cours -0.002803         0.039129        0.053001
# réseaux_sociaux        -0.106438        -0.028350        0.028274
# ...

# %% [markdown]
# Visulation exemple

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(df["etat_psychique_preparation "])

plt.pyplot.ylabel("nombre des etudiants")
plt.pyplot.xlabel("l'etat psychique pendat la semaine de preparation")
# Out:
# Text(0.5, 0, "l'etat psychique pendat la semaine de preparation")

# %%
#we can drop missing values along the column "price" as follows 
#df.dropna(subset=["price"], axis=0)

# %%
#pour lister les differntes types de notre dataframe
df.dtypes
# Out:
# age                             int64
# filiere                        object
# endroit_travail                object
# travail_equipe                  int64
# heure_dormir                   object
# sport_par_sem                  object
# activites_para                  int64
# rythme_formation               object
# compétences_enseignants        object
# communication_enseignants      object
# méthodes_pédagogiques          object
# etat_psychique_preparation     object
# etat_psychique_examen          object
# resultat_etudiant              object
# nombre_rattrapage               int64
# services_bibliothèques          int64
# transport_scolaire              int64
# orientation                     int64
# ressources_materials            int64
# Mauvais_Gestion_temps           int64
# qualite_logement                int64
# addiction_drogues               int64
# mauvais_choix_de_cours          int64
# réseaux_sociaux                 int64
# Barrieres_de_langage            int64
# ...

# %%
# check the data type of data frame "df" by .dtypes
print(df.dtypes)
# Out:
# age                             int64
# filiere                        object
# endroit_travail                object
# travail_equipe                  int64
# heure_dormir                   object
# sport_par_sem                  object
# activites_para                  int64
# rythme_formation               object
# compétences_enseignants        object
# communication_enseignants      object
# méthodes_pédagogiques          object
# etat_psychique_preparation     object
# etat_psychique_examen          object
# resultat_etudiant              object
# nombre_rattrapage               int64
# services_bibliothèques          int64
# transport_scolaire              int64
# orientation                     int64
# ressources_materials            int64
# Mauvais_Gestion_temps           int64
# qualite_logement                int64
# addiction_drogues               int64
# mauvais_choix_de_cours          int64
# réseaux_sociaux                 int64
# Barrieres_de_langage            int64
# ...
